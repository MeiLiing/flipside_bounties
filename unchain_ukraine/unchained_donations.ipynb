# %%
import pandas as pd
import requests
from newsapi import NewsApiClient

# %%
url = "https://google-news.p.rapidapi.com/v1/topic_headlines"

querystring = {"lang":"en","country":"US","topic":"CAAqIQgKIhtDQkFTRGdvSUwyMHZNRGQwTWpFU0FtVnVLQUFQAQ"}

headers = {
    'x-rapidapi-host': "google-news.p.rapidapi.com",
    'x-rapidapi-key': "ef357e99fbmshb1ef0c1e1a148c7p1536d1jsn2066b6a4c862"
    }

response = requests.request("GET", url, headers=headers, params=querystring)

print(response.text)
# Out:
# {"feed":{"title":"Ukraine - Latest - Google News","updated":"Mon, 28 Feb 2022 21:39:11 GMT","link":"https://news.google.com/topics/CAAqIQgKIhtDQkFTRGdvSUwyMHZNRGQwTWpFU0FtVnVLQUFQAQ?ceid=US:en&hl=en-US&gl=US","language":"en-US","subtitle":"Google News","rights":"2022 Google Inc."},"articles":[{"id":"1317602298","title":"Live updates: Russia invades Ukraine - CNN","link":"https://news.google.com/__i/rss/rd/articles/CBMiTGh0dHBzOi8vd3d3LmNubi5jb20vZXVyb3BlL2xpdmUtbmV3cy91a3JhaW5lLXJ1c3NpYS1uZXdzLTAyLTI4LTIyL2luZGV4Lmh0bWzSAQA?oc=5","published":"Mon, 28 Feb 2022 21:14:00 GMT","sub_articles":[{"url":"https://news.google.com/__i/rss/rd/articles/CBMiTGh0dHBzOi8vd3d3LmNubi5jb20vZXVyb3BlL2xpdmUtbmV3cy91a3JhaW5lLXJ1c3NpYS1uZXdzLTAyLTI4LTIyL2luZGV4Lmh0bWzSAQA?oc=5","title":"Live updates: Russia invades Ukraine","publisher":"CNN"},{"url":"https://news.google.com/__i/rss/rd/articles/CBMiK2h0dHBzOi8vd3d3LnlvdXR1YmUuY29tL3dhdGNoP3Y9OW0wWmVPZXBiM1HSAQA?oc=5","title":"Russia, Ukraine start ceasefire
# ...

# %%
import http.client

conn = http.client.HTTPSConnection("google-news.p.rapidapi.com")

headers = {
    'x-rapidapi-host': "google-news.p.rapidapi.com",
    'x-rapidapi-key': "ef357e99fbmshb1ef0c1e1a148c7p1536d1jsn2066b6a4c862"
    }

conn.request("GET", "/v1/topic_headlines?lang=en&country=US&topic=CAAqIQgKIhtDQkFTRGdvSUwyMHZNRGQwTWpFU0FtVnVLQUFQAQ", headers=headers)

res = conn.getresponse()
data = res.read()

print(data.decode("utf-8"))
# Out:
# {"feed":{"title":"Ukraine - Latest - Google News","updated":"Mon, 28 Feb 2022 22:02:18 GMT","link":"https://news.google.com/topics/CAAqIQgKIhtDQkFTRGdvSUwyMHZNRGQwTWpFU0FtVnVLQUFQAQ?ceid=US:en&hl=en-US&gl=US","language":"en-US","subtitle":"Google News","rights":"2022 Google Inc."},"articles":[{"id":"CBMiTGh0dHBzOi8vd3d3LmNubi5jb20vZXVyb3BlL2xpdmUtbmV3cy91a3JhaW5lLXJ1c3NpYS1uZXdzLTAyLTI4LTIyL2luZGV4Lmh0bWzSAQA","title":"Live updates: Russia invades Ukraine - CNN","link":"https://news.google.com/__i/rss/rd/articles/CBMiTGh0dHBzOi8vd3d3LmNubi5jb20vZXVyb3BlL2xpdmUtbmV3cy91a3JhaW5lLXJ1c3NpYS1uZXdzLTAyLTI4LTIyL2luZGV4Lmh0bWzSAQA?oc=5","published":"Mon, 28 Feb 2022 21:47:00 GMT","sub_articles":[],"source":{"href":"https://www.cnn.com","title":"CNN"}},{"id":"1318856574","title":"Russia launches multiple rocket attacks in Kharkiv and renews Kyiv assault - The Guardian","link":"https://news.google.com/__i/rss/rd/articles/CBMieWh0dHBzOi8vd3d3LnRoZWd1YXJkaWFuLmNvbS93b3JsZC8yMDIyL2ZlYi8yOC9ydXNza
# ...

# %%
news_key = '21661859fc22453f9fe70c9e59b9d6aa'

# %%
# Init
newsapi = NewsApiClient(api_key='21661859fc22453f9fe70c9e59b9d6aa')

# /v2/top-headlines
top_headlines = newsapi.get_top_headlines(q='ukraine',
                                          category='general',
                                          language='en',
                                          country='us')
print(top_headlines)
# Out:
# {'status': 'ok', 'totalResults': 8, 'articles': [{'source': {'id': 'cbs-news', 'name': 'CBS News'}, 'author': None, 'title': 'Ukraine seeks "immediate ceasefire" and Russian withdrawal in 1st direct talks during Putin\'s ongoing invasion - CBS News', 'description': 'As Putin talks nuclear "deterrence" and continues his assault on Ukraine, Kyiv says the "key issue" in talks is "an immediate ceasefire" and Russian withdrawal.', 'url': 'https://www.cbsnews.com/live-updates/russia-ukraine-news-kyiv-war-putin-invasion-talks-today/', 'urlToImage': 'https://cbsnews1.cbsistatic.com/hub/i/r/2022/02/28/7712bd2b-7ba5-471a-ae55-cb6d8809cddb/thumbnail/1200x630/2f7cd2dd806e68466fc4b9161dcf4568/kharkiv-russia-ukraine-fighting-1238802925.jpg', 'publishedAt': '2022-02-28T20:32:17Z', 'content': 'France\'s President Emmanuel Macron spoke Monday with Russian leader Vladimir Putin and "reiterated the request of the international community to end the Russian offensive against Ukraine."\xa0\r\nAccordin… [+
# ...

# %%
news = pd.json_normalize(top_headlines['articles'])
news = news.drop(columns=['author','description','urlToImage','content','source.id'])
# news.publishedAt.dt.round(freq='H')

news.head()
# Out:
#                                                title  \
# 0  Ukraine seeks "immediate ceasefire" and Russia...
# 1  Ukraine conflict likely to delay Rosalind Fran...
# 2  Stocks fall, ruble dives as Russia sanctions h...
# 3         Live updates: Russia invades Ukraine - CNN
# 4  Maksim Chmerkovskiy Arrested And Released In K...
#
#                                                  url           publishedAt  \
# 0  https://www.cbsnews.com/live-updates/russia-uk...  2022-02-28T20:32:17Z
# 1  https://www.dailymail.co.uk/sciencetech/articl...  2022-02-28T18:45:18Z
# 2  https://www.reuters.com/markets/europe/global-...  2022-02-28T18:41:00Z
# 3  https://www.cnn.com/europe/live-news/ukraine-r...  2022-02-28T18:31:00Z
# 4  https://deadline.com/2022/02/maksim-chmerkovsk...  2022-02-28T18:05:00Z
#
#   source.name
# 0    CBS News
# 1  Daily Mail
# 2     Reuters
# 3         CNN
# 4    Deadline
